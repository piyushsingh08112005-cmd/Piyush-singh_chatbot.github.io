# %% [markdown]
# # Hello World in Python
#
# The classic first program — printing a message to the console.

# %% [markdown]
# ## Basic Output
# The `print()` function sends text to the console.

# %%
print("Hello, World!")

# %% [markdown]
# ## Variations

# %%
name = "Piyush"
print(f"Hello, {name}!")
print("Hello,", name, "— welcome to Python!")
